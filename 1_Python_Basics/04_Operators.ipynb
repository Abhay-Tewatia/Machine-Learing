# %%
# Arithmethic Operators
a = 10
b = 5
addresult = a+b
subsresult = a-b
multiplyresult = a*b
divresult = a/b
floor_divresult = a//b
moderesult  = a%b
exponentresult = a**b
print(addresult) 
print(subsresult)
print(multiplyresult)
print(divresult)
print(floor_divresult)
print(moderesult)
print(exponentresult)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
# comparision operators
a = 10
b = 10

print(a==b)
# Out:
# True

# %%
str1 = "abhi"
str2 = "abhi"
print(str1==str2)
# Out:
# True

# %%
str1 = "abhi"
str2 = "bhi"
print(str1!=str2)
# Out:
# True

# %%
nums1 = 45
nums2  = 45
print(nums1>nums2)
print(nums1<nums2)
# Out:
# False
# False

# %%
# greater than or equal to
print(nums1>=nums2)
# less than or equal to
print(nums1<=nums2)
# Out:
# True
# True

# %%
# logical operators
x = 10
y = 5
print(x > 5 and y < 10)  # True
print(x > 15 or y < 10)   # True
print(not(x > 15))         # True
# Out:
# True
# True
# True
