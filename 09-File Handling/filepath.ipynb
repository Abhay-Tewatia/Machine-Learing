# %%
import os
cwd = os.getcwd()
print(f"Current working directory: {cwd}")
# Out:
# Current working directory: c:\Users\Abhay Tewatia\OneDrive\Desktop\Machine-Learing\09-File Handling

# %%
new_directory = "package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created.")
# Out:
# Directory 'package' created.

# %%
# listing file and directories
items = os.listdir('.')
print(items)
# Out:
# ['destination.txt', 'example.bin', 'example.txt', 'fileOperation.ipynb', 'filepath.ipynb', 'package']

# %%
# joining paths
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name, file_name)
print(f"Full path: {full_path}")

# %%
path = 'example.txt'
if os.path.exists(path):
    print(f"The path '{path}' exists.")
else:
    print(f"The path '{path}' does not exist.")
# Out:
# The path 'example.txt' exists.

# %%
# checking if a path is a file or direcotory
import os
path = 'example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' does not exist.")
# Out:
# The path 'example.txt' is a file.

# %%
# getting the absolute path
relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(f"Absolute path: {absolute_path}")
# Out:
# Absolute path: c:\Users\Abhay Tewatia\OneDrive\Desktop\Machine-Learing\09-File Handling\example.txt
