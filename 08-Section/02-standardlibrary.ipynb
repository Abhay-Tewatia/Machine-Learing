# %% [markdown]
# Standard Library Overview

# %%
Python Standard library is  a collection of modules and packages that come pre-installed with python. It provides a wide range of functionalities, including file I/O, regular expressions, networking and more. The standard library is organized into modules, which are individual files containing Python code, and packages, which are directories containing multiple modules.

# %%
import array
arr = array.array('i', [1, 2, 3, 4, 5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(16))
print(math.factorial(5))
# Out:
# 4.0
# 120

# %%
# random
import random
print(random.randint(1, 10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 8
# banana

# %%
# file and Directory Access
import os
print(os.getcwd())
# Out:
# c:\Users\Abhay Tewatia\OneDrive\Desktop\Machine-Learing\08-Section

# %%
# High Level operations on files and collection of files
import shutil
shutil.copy('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
# Data serialization and deserialization
import json
data = {'name': 'John', 'age': 30, 'city': 'New York'}
json_string = json.dumps(data)
print(json_string)
print(type(json_string))

print(json.loads(json_string))
# Out:
# {"name": "John", "age": 30, "city": "New York"}
# <class 'str'>
# {'name': 'John', 'age': 30, 'city': 'New York'}

# %%
# csv 
import csv

# Writing to csv file
with open('data.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age', 'City'])
    writer.writerow(['John', 30, 'New York'])
    writer.writerow(['Jane', 25, 'Los Angeles'])

# Reading from csv file
with open('data.csv', mode = 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            print(row)
# Out:
# ['Name', 'Age', 'City']
# ['John', '30', 'New York']
# ['Jane', '25', 'Los Angeles']

# %%
# datetime
from datetime import datetime, timedelta
now = datetime.now()
print("Current date and time:", now)

yesterday = now - timedelta(days=1)
print("Yesterday's date and time:", yesterday)
# Out:
# Current date and time: 2026-07-21 14:48:38.880996
# Yesterday's date and time: 2026-07-20 14:48:38.880996

# %%
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1784625614.5087428
# 1784625616.510672

# %%
# regular expressions
import re

pattern = r'\b\w+@\w+\.\w+\b'
text = "Please contact us at info@example.com or support@example.com for more information."

matches = re.findall(pattern, text)
matche = re.search(pattern, text)
print("Email addresses found:", matches, matche.group())
# Out:
# Email addresses found: ['info@example.com', 'support@example.com'] info@example.com
